# %% [markdown]
# <a href="https://colab.research.google.com/github/taisriquinho/Curso-Machine-Learning-/blob/main/03-Regressao/Regressao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Dados registrados

# %%
temperatura = np.array([30, 25, 36, 18, 25, 29, 30, 33, 37, 31, 26, 37, 29, 26, 30, 31, 34, 38])

# %%
numero_sorvete = np.array([20, 12, 50, 10, 18, 25, 26, 32, 48,22 ,16, 52, 24, 20, 28, 29, 35, 40])

# %%
df = pd.DataFrame({'temperatura':temperatura, 'numero_sorvete': numero_sorvete})

# %%
df.head()
# Out:
#    temperatura  numero_sorvete
# 0           30              20
# 1           25              12
# 2           36              50
# 3           18              10
# 4           25              18

# %% [markdown]
# Separação de variável independente e variável dependente

# %%
x = df['temperatura'].to_numpy()

# %%
y = df['numero_sorvete'].to_numpy()

# %%
from sklearn.model_selection import train_test_split

# %%
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2)

# %% [markdown]
# Treinando o modelo

# %%
from sklearn.linear_model import LinearRegression

# %%
modelo = LinearRegression()
modelo.fit(x_treino.reshape(-1, 1), y_treino.reshape(-1, 1))
# Out:
# LinearRegression()

# %% [markdown]
# Realizando a previsão do número de sorvetes a serem vendidos

# %%
y_previsto = modelo.predict(x_teste.reshape(-1,1))

# %%
plt.plot(range(y_previsto.shape[0]), y_previsto, 'r--')
plt.plot(range(y_teste.shape[0]), y_teste, 'g--')
plt.legend(['Sorvetes previstos', 'Sorvetes vendidos'])
plt.xlabel('indice')
plt.ylabel("Sorvetes")
plt.show()
